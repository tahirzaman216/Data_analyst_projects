# %%
import pandas as pd

# %%
dict1 = {"Name" : ["Tahir", "Zaman", "khan", "Zeeshan", "Qasam", "Manan", "Hamza"],"Marks" : [98,89,99,87,90,83,99], "Gender" : ["Male","Male","Male","Male","Male","Male","Male"]}


df1 = pd.DataFrame(dict1)
df1
# Out:
#       Name  Marks Gender
# 0    Tahir     98   Male
# 1    Zaman     89   Male
# 2     khan     99   Male
# 3  Zeeshan     87   Male
# 4    Qasam     90   Male
# 5    Manan     83   Male
# 6    Hamza     99   Male

# %%
df1.head(3)
# Out:
#     Name  Marks Gender
# 0  Tahir     98   Male
# 1  Zaman     89   Male
# 2   khan     99   Male

# %%
df1.tail(3)
# Out:
#     Name  Marks Gender
# 4  Qasam     90   Male
# 5  Manan     83   Male
# 6  Hamza     99   Male

# %%
df1.shape
# Out:
# (7, 3)

# %%
print("Number of rows", df1.shape[0])
print("Number of columns", df1.shape[1])
# Out:
# Number of rows 7
# Number of columns 3

# %%
df1.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    7 non-null      str
#  1   Marks   7 non-null      int64
#  2   Gender  7 non-null      str
# dtypes: int64(1), str(2)
# memory usage: 300.0 bytes

# %%
df1.isnull().sum()
# Out:
# Name      0
# Marks     0
# Gender    0
# dtype: int64

# %%
df1.describe(include="all")
# Out:
#          Name      Marks Gender
# count       7   7.000000      7
# unique      7        NaN      1
# top     Tahir        NaN   Male
# freq        1        NaN      7
# mean      NaN  92.142857    NaN
# std       NaN   6.491753    NaN
# min       NaN  83.000000    NaN
# 25%       NaN  88.000000    NaN
# 50%       NaN  90.000000    NaN
# 75%       NaN  98.500000    NaN
# max       NaN  99.000000    NaN

# %%
df1
# Out:
#       Name  Marks Gender
# 0    Tahir     98   Male
# 1    Zaman     89   Male
# 2     khan     99   Male
# 3  Zeeshan     87   Male
# 4    Qasam     90   Male
# 5    Manan     83   Male
# 6    Hamza     99   Male

# %%
df1["Gender"].unique()
# Out:
# <StringArray>
# ['Male']
# Length: 1, dtype: str

# %%
df1["Gender"].nunique()
# Out:
# 1

# %%
df1["Gender"].value_counts()
# Out:
# Gender
# Male    7
# Name: count, dtype: int64

# %%
df1["Marks"] >= 90
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4     True
# 5    False
# 6     True
# Name: Marks, dtype: bool

# %%
df1[df1["Marks"] >= 90]
# Out:
#     Name  Marks Gender
# 0  Tahir     98   Male
# 2   khan     99   Male
# 4  Qasam     90   Male
# 6  Hamza     99   Male

# %%
len(df1[(df1["Marks"]>=90)  &  (df1["Marks"]<=100)])
# Out:
# 4

# %%
sum(df1["Marks"].between(90,100))
# Out:
# 4

# %%
df1["Marks"].mean()
# Out:
# np.float64(92.14285714285714)

# %%
df1["Marks"].min()
# Out:
# np.int64(83)

# %%
df1["Marks"].max()
# Out:
# np.int64(99)

# %%
def halfMarks(x):
    return x/2

# %%
df1["Half_Marks"] = df1["Marks"].apply(halfMarks)

# %%
df1
# Out:
#       Name  Marks Gender  Half_Marks
# 0    Tahir     98   Male        49.0
# 1    Zaman     89   Male        44.5
# 2     khan     99   Male        49.5
# 3  Zeeshan     87   Male        43.5
# 4    Qasam     90   Male        45.0
# 5    Manan     83   Male        41.5
# 6    Hamza     99   Male        49.5

# %%
df1.drop(columns=["Half Marks"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 df1.drop(columns=["Half Marks"])
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\frame.py:6288, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    6130 def drop(
#    6131     self,
#    6132     labels: IndexLabel | ListLike = None,
#    (...)   6139     errors: IgnoreRaise = "raise",
#    6140 ) -> DataFrame | None:
#    6141     """
#    6142     Drop specified labels from rows or columns.
#    6143
#    (...)   6286             weight  1.0     0.8
#    6287     """
# -> 6288     return super().drop(
#    6289         labels=labels,
#    6290         axis=axis,
#    6291         index=index,
#    6292         columns=columns,
#    6293         level=level,
# ...

# %%
df1
# Out:
#       Name  Marks Gender  Half_Marks
# 0    Tahir     98   Male        49.0
# 1    Zaman     89   Male        44.5
# 2     khan     99   Male        49.5
# 3  Zeeshan     87   Male        43.5
# 4    Qasam     90   Male        45.0
# 5    Manan     83   Male        41.5
# 6    Hamza     99   Male        49.5

# %%
df1["Male_Female"] = df1["Gender"].map({"Male":1, "Female":0})

# %%
df1
# Out:
#       Name  Marks Gender  Half_Marks  Male_Female
# 0    Tahir     98   Male        49.0            1
# 1    Zaman     89   Male        44.5            1
# 2     khan     99   Male        49.5            1
# 3  Zeeshan     87   Male        43.5            1
# 4    Qasam     90   Male        45.0            1
# 5    Manan     83   Male        41.5            1
# 6    Hamza     99   Male        49.5            1

# %%
df1.drop("Male_Female", axis=1)
# Out:
#       Name  Marks Gender  Half_Marks
# 0    Tahir     98   Male        49.0
# 1    Zaman     89   Male        44.5
# 2     khan     99   Male        49.5
# 3  Zeeshan     87   Male        43.5
# 4    Qasam     90   Male        45.0
# 5    Manan     83   Male        41.5
# 6    Hamza     99   Male        49.5

# %%
df1.drop(["Male_Female","Half_Marks"], axis=1)
# Out:
#       Name  Marks Gender
# 0    Tahir     98   Male
# 1    Zaman     89   Male
# 2     khan     99   Male
# 3  Zeeshan     87   Male
# 4    Qasam     90   Male
# 5    Manan     83   Male
# 6    Hamza     99   Male

# %%
df1
# Out:
#       Name  Marks Gender  Half_Marks  Male_Female
# 0    Tahir     98   Male        49.0            1
# 1    Zaman     89   Male        44.5            1
# 2     khan     99   Male        49.5            1
# 3  Zeeshan     87   Male        43.5            1
# 4    Qasam     90   Male        45.0            1
# 5    Manan     83   Male        41.5            1
# 6    Hamza     99   Male        49.5            1

# %%
df1.drop(["Male_Female","Half_Marks"], axis=1, inplace=True)

# %%
df1
# Out:
#       Name  Marks Gender
# 0    Tahir     98   Male
# 1    Zaman     89   Male
# 2     khan     99   Male
# 3  Zeeshan     87   Male
# 4    Qasam     90   Male
# 5    Manan     83   Male
# 6    Hamza     99   Male

# %%
df1.columns
# Out:
# Index(['Name', 'Marks', 'Gender'], dtype='str')

# %%
df1
# Out:
#       Name  Marks Gender
# 0    Tahir     98   Male
# 1    Zaman     89   Male
# 2     khan     99   Male
# 3  Zeeshan     87   Male
# 4    Qasam     90   Male
# 5    Manan     83   Male
# 6    Hamza     99   Male

# %%
df1.sort_values(by="Marks")
# Out:
#       Name  Marks Gender
# 5    Manan     83   Male
# 3  Zeeshan     87   Male
# 1    Zaman     89   Male
# 4    Qasam     90   Male
# 0    Tahir     98   Male
# 2     khan     99   Male
# 6    Hamza     99   Male

# %%
df1.sort_values(by="Marks", ascending=False)
# Out:
#       Name  Marks Gender
# 2     khan     99   Male
# 6    Hamza     99   Male
# 0    Tahir     98   Male
# 4    Qasam     90   Male
# 1    Zaman     89   Male
# 3  Zeeshan     87   Male
# 5    Manan     83   Male

# %%
df1[df1["Gender"] == "Male"][["Name", "Marks"]]
# Out:
#       Name  Marks
# 0    Tahir     98
# 1    Zaman     89
# 2     khan     99
# 3  Zeeshan     87
# 4    Qasam     90
# 5    Manan     83
# 6    Hamza     99
